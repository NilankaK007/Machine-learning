# %%
import numpy as np
import pandas as pd
df1=pd.DataFrame(np.random.rand(10,4),columns=('col1','col2','col3','col4'))

# %%
print(df1)
# Out:
#        col1      col2      col3      col4
# 0  0.665061  0.364681  0.235522  0.280844
# 1  0.015331  0.367111  0.339486  0.533397
# 2  0.078718  0.881335  0.008414  0.114733
# 3  0.581003  0.386140  0.436216  0.043178
# 4  0.156944  0.046214  0.674797  0.955766
# 5  0.098716  0.814599  0.380509  0.820925
# 6  0.389032  0.210428  0.099018  0.323732
# 7  0.183589  0.097332  0.111122  0.298341
# 8  0.845846  0.971430  0.299585  0.236877
# 9  0.287424  0.215150  0.739996  0.866422

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.plot(subplots=True,figsize=(8,8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df1.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1.plot(kind="density")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1.plot(kind="area")
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind="hexbin",x='col1',y='col2')
# Out:
# <AxesSubplot:xlabel='col1', ylabel='col2'>

# %%
df1.plot(kind="pie",subplots=True)
# Out:
# array([<AxesSubplot:ylabel='col1'>, <AxesSubplot:ylabel='col2'>,
#        <AxesSubplot:ylabel='col3'>, <AxesSubplot:ylabel='col4'>],
#       dtype=object)

# %%
df1.plot(kind="pie",y='col1')
# Out:
# <AxesSubplot:ylabel='col1'>

# %%
df1.plot(kind="scatter",x='col1',y='col2')
# Out:
# <AxesSubplot:xlabel='col1', ylabel='col2'>
