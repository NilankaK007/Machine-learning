# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Heart.csv')

# %%
data.head(10)
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
# 5           6   56    1    nontypical     120   236    0        0    178
# 6           7   62    0  asymptomatic     140   268    0        2    160
# 7           8   57    0  asymptomatic     120   354    0        0    163
# 8           9   63    1  asymptomatic     130   254    0        2    147
# 9          10   53    1  asymptomatic     140   203    1        2    155
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
data['Ca'].fillna(data['Ca'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            0
# Thal          2
# AHD           0
# dtype: int64

# %%
data['Thal'].fillna(data['Thal'].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            0
# Thal          0
# AHD           0
# dtype: int64

# %%
X=data.drop(['AHD','ChestPain','Thal'],axis=1)
Y=data['AHD']

# %%
from sklearn.preprocessing import OneHotEncoder
encoder=OneHotEncoder(sparse_output=False)
encoded=encoder.fit_transform(data[['Sex']],data[['ChestPain']])
encoded=encoder.fit_transform(data[['RestECG']],data[['Oldpeak']])

# %%
data.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns
scaled_data=scaler.fit_transform(data[numeric_cols])

# %%
from sklearn.svm import SVC

# %%
model=SVC(kernel='linear')

# %% [markdown]
# model.fit(x_train,y_train)

# %%
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=model.predict(x_test)

# %%
intercept=model.intercept_
print("Intercept:",intercept)
# Out:
# Intercept: [-0.08795572]

# %%
coefficient=model.coef_
print("Coefficient:",coefficient)
# Out:
# Coefficient: [[ 0.00167936 -0.03344855  1.16712871  0.00810143  0.00779419 -0.1091839
#   -0.00862514 -0.02499956  0.73509796  0.35556719  0.16551498  1.07245997]]

# %%
from sklearn.metrics import f1_score,accuracy_score,recall_score,precision_score,confusion_matrix

# %%
print('F1 score: ',f1_score(y_pred,y_test,average='weighted'))
print('Accuracy score: ',accuracy_score(y_pred,y_test))
print('Recall score: ',recall_score(y_pred,y_test,average='weighted'))
print('Precision score: ',precision_score(y_pred,y_test,average='weighted'))
print('Confusion matrix: ',confusion_matrix(y_pred,y_test))
# Out:
# F1 score:  0.8131868131868132
# Accuracy score:  0.8131868131868132
# Recall score:  0.8131868131868132
# Precision score:  0.8149563202754692
# Confusion matrix:  [[37 10]
#  [ 7 37]]

# %%
excepted=y_test[:5].values
predict=y_pred[:5]
print('Actual values:',excepted)
print('Predict values:',predict)
# Out:
# Actual values: ['No' 'No' 'No' 'No' 'No']
# Predict values: ['No' 'No' 'Yes' 'No' 'No']

# %%
comparison=pd.DataFrame({
    'Excepted':y_test[:5].values,
    'Predicted':y_pred[:5]
})

# %%
print(comparison)
# Out:
#   Excepted Predicted
# 0       No        No
# 1       No        No
# 2       No       Yes
# 3       No        No
# 4       No        No
