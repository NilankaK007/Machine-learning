# %%
####Linear regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
data=pd.read_csv('Advertising.csv')

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
X=data[['TV']]
Y=data['Sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
intercept=lr.intercept_
print('Intercept: ',intercept)
# Out:
# Intercept:  6.9309215720959765

# %%
coefficient=lr.coef_
print('Coefficient:',coefficient)
# Out:
# Coefficient: [0.04908636]

# %%
y_pred=lr.predict(x_test)

# %%
actual=y_test[:5].values
predicted=y_pred[:5]
print('Actual values: ',actual)
print('Predicted values: ',predicted)
# Out:
# Actual values:  [23.8 12.2 11.4  8.6 16.1]
# Predicted values:  [21.48011974 17.08198156 11.65302975 10.1755302  20.70946383]

# %%
plt.scatter(X,Y,color='blue',label='Data')
plt.xlabel('TV')
plt.ylabel('sales')
plt.plot(x_test,y_pred,color='red',label='Regression line')
plt.legend()
plt.show()

# %%
mse=mean_squared_error(y_pred,y_test)
mae=mean_absolute_error(y_pred,y_test)
r2=r2_score(y_pred,y_test)
rmse=np.sqrt(mse)
print('MSE: ',mse)
print('MAE: ',mae)
print('R score: ',r2)
print('RMSE: ',rmse)
# Out:
# MSE:  11.904620963959578
# MAE:  2.6313881262673693
# R score:  0.40031048218241017
# RMSE:  3.4503073723886657

# %%
#### multiple regression

# %%
X=data[['TV','Radio','Newspaper']]
Y=data['Sales']

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25)

# %%
mlr=LinearRegression()

# %%
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
intercept=mlr.intercept_
print('Intercept: ',intercept)
# Out:
# Intercept:  3.103183647003032

# %%
coefficient=mlr.coef_
print('Coefficient:',coefficient)
# Out:
# Coefficient: [0.04436775 0.18948241 0.00038467]

# %%
y_pred=mlr.predict(x_test)

# %%
actual=y_test[:5].values
predicted=y_pred[:5]
print('Actual values: ',actual)
print('Predicted values: ',predicted)
# Out:
# Actual values:  [ 5.3 11.8 23.8 11.2 18.5]
# Predicted values:  [ 9.01190951 11.56063843 21.86873548  9.99381403 17.67302485]

# %%
feature=['TV','Radio','Newspaper']
for i in feature:
    plt.scatter(data[i],Y,color='blue',label='Data')
    plt.xlabel(i)
    plt.ylabel('sales')
    plt.plot(x_test,y_pred,color='red',label='Regression line')
    plt.legend()
    plt.show()

# %%
mse=mean_squared_error(y_pred,y_test)
mae=mean_absolute_error(y_pred,y_test)
r2=r2_score(y_pred,y_test)
rmse=np.sqrt(mse)
print('MSE: ',mse)
print('MAE: ',mae)
print('R score: ',r2)
print('RMSE: ',rmse)
# Out:
# MSE:  2.9259178851621708
# MAE:  1.2257405382946867
# R score:  0.8475952963822809
# RMSE:  1.7105314627805508
